# %% [markdown]
# <a href="https://colab.research.google.com/github/pranavsrinivas29/data_analysis/blob/main/Pandas4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive

# %%
# from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df=pd.read_csv('/content/drive/MyDrive/survey_results_public.csv')

# %%
# Data Analysis
statistics = df.describe()

print(statistics)
# Out:
#          Respondent     CompTotal  ConvertedComp   WorkWeekHrs    CodeRevHrs  \
# count  88883.000000  5.594500e+04   5.582300e+04  64503.000000  49790.000000
# mean   44442.000000  5.519014e+11   1.271107e+05     42.127197      5.084308
# std    25658.456325  7.331926e+13   2.841523e+05     37.287610      5.513931
# min        1.000000  0.000000e+00   0.000000e+00      1.000000      0.000000
# 25%    22221.500000  2.000000e+04   2.577750e+04     40.000000      2.000000
# 50%    44442.000000  6.200000e+04   5.728700e+04     40.000000      4.000000
# 75%    66662.500000  1.200000e+05   1.000000e+05     44.750000      6.000000
# max    88883.000000  1.000000e+16   2.000000e+06   4850.000000     99.000000
#
#                 Age
# count  79210.000000
# mean      30.336699
# std        9.178390
# min        1.000000
# 25%       24.000000
# 50%       29.000000
# 75%       35.000000
# max       99.000000

# %%
# Computing correlation matrix
correlation_matrix = df.corr()

# Computing covariance matrix
covariance_matrix = df.cov()

print("Correlation Matrix:")
print(correlation_matrix)
print("\nCovariance Matrix:")
print(covariance_matrix)
# Out:
# Correlation Matrix:
#                Respondent  CompTotal  ConvertedComp  WorkWeekHrs  CodeRevHrs  \
# Respondent       1.000000  -0.003357       0.002930    -0.004589   -0.005240
# CompTotal       -0.003357   1.000000       0.039725     0.003074    0.061090
# ConvertedComp    0.002930   0.039725       1.000000     0.013908   -0.021261
# WorkWeekHrs     -0.004589   0.003074       0.013908     1.000000    0.021092
# CodeRevHrs      -0.005240   0.061090      -0.021261     0.021092    1.000000
# Age             -0.001829   0.016500       0.108268     0.019976   -0.022486
#
#                     Age
# Respondent    -0.001829
# CompTotal      0.016500
# ConvertedComp  0.108268
# WorkWeekHrs    0.019976
# CodeRevHrs    -0.022486
# Age            1.000000
#
# Covariance Matrix:
#                  Respondent     CompTotal  ConvertedComp   WorkWeekHrs  \
# Respondent     6.583564e+08 -6.315381e+15   2.136238e+07 -4.394191e+03
# ...

# %%
# Creating a DataFrame
data = {'Name': ['Alice', 'Bob', 'Charlie', 'Alice', 'Bob', 'Charlie'],
        'Subject': ['Math', 'Math', 'Math', 'Science', 'Science', 'Science'],
        'Score': [85, 90, 88, 92, 89, 94]}
df1 = pd.DataFrame(data)

# Creating a pivot table
pivot_table = df1.pivot_table(index='Name', columns='Subject', values='Score', aggfunc='mean')

print("Pivot Table:")
print(pivot_table)
# Out:
# Pivot Table:
# Subject  Math  Science
# Name
# Alice      85       92
# Bob        90       89
# Charlie    88       94

# %%
df.head(2)
# Out:
#    Respondent                              MainBranch Hobbyist  \
# 0           1  I am a student who is learning to code      Yes
# 1           2  I am a student who is learning to code       No
#
#                OpenSourcer                                         OpenSource  \
# 0                    Never  The quality of OSS and closed source software ...
# 1  Less than once per year  The quality of OSS and closed source software ...
#
#                                Employment                 Country  \
# 0  Not employed, and not looking for work          United Kingdom
# 1      Not employed, but looking for work  Bosnia and Herzegovina
#
#           Student                                            EdLevel  \
# 0              No                          Primary/elementary school
# 1  Yes, full-time  Secondary school (e.g. American high school, G...
#
#   UndergradMajor  ...                            WelcomeChange  \
# ...

# %%
pivot_table2 = df.pivot_table(index='Employment', columns='Country', values='Age', aggfunc='mean')
pivot_table2
# Out:
# Country                                             Afghanistan    Albania  \
# Employment
# Employed full-time                                    30.071429  25.250000
# Employed part-time                                    23.666667  24.000000
# Independent contractor, freelancer, or self-emp...    25.000000  29.714286
# Not employed, and not looking for work                      NaN  17.000000
# Not employed, but looking for work                    19.500000  21.250000
# Retired                                                     NaN        NaN
#
# Country                                               Algeria  Andorra  \
# Employment
# Employed full-time                                  31.264706      NaN
# Employed part-time                                  32.200000      NaN
# Independent contractor, freelancer, or self-emp...  27.615385     50.0
# Not employed, and not looking for work              21.666667     19.5
# ...
