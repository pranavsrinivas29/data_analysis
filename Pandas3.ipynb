# %% [markdown]
# <a href="https://colab.research.google.com/github/pranavsrinivas29/data_analysis/blob/main/Pandas3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive

# %%
# from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df=pd.read_csv('/content/drive/MyDrive/survey_results_public.csv')

# %%
df.head(3)
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
#
#                OpenSourcer                                         OpenSource  \
# 0                    Never  The quality of OSS and closed source software ...
# 1  Less than once per year  The quality of OSS and closed source software ...
# 2                    Never  The quality of OSS and closed source software ...
#
#                                Employment                 Country  \
# 0  Not employed, and not looking for work          United Kingdom
# 1      Not employed, but looking for work  Bosnia and Herzegovina
# 2                      Employed full-time                Thailand
#
#           Student                                            EdLevel  \
# ...

# %%
#Using Apply function
def triple_age(x):
  return x*3

df['Tripled_Age'] = df['Age'].apply(triple_age)
df.head(2)
# Out:
#    Respondent                              MainBranch Hobbyist  \
# 0           1  I am a student who is learning to code      Yes
# 1           2  I am a student who is learning to code       No
#
#                OpenSourcer                                         OpenSource  \
# 0                    Never  The quality of OSS and closed source software ...
# 1  Less than once per year  The quality of OSS and closed source software ...
#
#                                Employment                 Country  \
# 0  Not employed, and not looking for work          United Kingdom
# 1      Not employed, but looking for work  Bosnia and Herzegovina
#
#           Student                                            EdLevel  \
# 0              No                          Primary/elementary school
# 1  Yes, full-time  Secondary school (e.g. American high school, G...
#
#   UndergradMajor  ...                                       SONewContent  \
# ...

# %%
# Creating a dictionary to map values
# Used less values in mapping for easy execution
age_mapping = {25.0: 'Middle-Age', 14.0: 'Young-aged', 19.0: 'Adult'}

# Creating a new column 'Age_Category' using map
df['Age_Category'] = df['Age'].map(age_mapping)

print(df.head(2))
# Out:
#    Respondent                              MainBranch Hobbyist  \
# 0           1  I am a student who is learning to code      Yes
# 1           2  I am a student who is learning to code       No
#
#                OpenSourcer                                         OpenSource  \
# 0                    Never  The quality of OSS and closed source software ...
# 1  Less than once per year  The quality of OSS and closed source software ...
#
#                                Employment                 Country  \
# 0  Not employed, and not looking for work          United Kingdom
# 1      Not employed, but looking for work  Bosnia and Herzegovina
#
#           Student                                            EdLevel  \
# 0              No                          Primary/elementary school
# 1  Yes, full-time  Secondary school (e.g. American high school, G...
#
#   UndergradMajor  ...   Age Gender Trans                Sexuality Ethnicity  \
# ...

# %%
# Creating map for all values
# Mapping age ranges using a dictionary
# Converting float values to integers
# Handling NaN values and converting the 'Age' column to integers
df['Age'] = df['Age'].fillna(0).astype(int)


df.head(5)


# Mapping age ranges using a dictionary
age_ranges = {range(0, 30): 'Young', range(30, 40): 'Middle-aged', range(40, 100): 'Old'}

# Applying the mapping using map
df['Age_Category'] = df['Age'].map(lambda x: next((v for k, v in age_ranges.items() if x in k), None))

df.head(10)
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
# 5           6  I am not primarily a developer, but I write co...      Yes
# 6           7                     I am a developer by profession       No
# 7           8                        I code primarily as a hobby      Yes
# 8           9                     I am a developer by profession      Yes
# 9          10                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# ...

# %%
# Merge
# Creating two DataFrames
df1 = pd.DataFrame({'ID': [1, 2, 3], 'Name': ['Alice', 'Bob', 'Charlie']})
df2 = pd.DataFrame({'ID': [2, 3, 4], 'Salary': [50000, 60000, 70000]})

# Merging on the 'ID' column
merged_df = pd.merge(df1, df2, on='ID', how='inner')

print(merged_df)
# Out:
#    ID     Name  Salary
# 0   2      Bob   50000
# 1   3  Charlie   60000

# %%
# Creating a DataFrame
data = {'Name': ['Alice', 'Bob', 'Charlie', 'Alice', 'Bob', 'Charlie'],
        'Subject': ['Math', 'Math', 'Math', 'Science', 'Science', 'Science'],
        'Score': [85, 90, 88, 92, 89, 94]}
df = pd.DataFrame(data)

# Grouping by 'Name' and calculating the mean score
grouped_data = df.groupby('Name')['Score'].mean().reset_index()

print(grouped_data)
# Out:
#       Name  Score
# 0    Alice   88.5
# 1      Bob   89.5
# 2  Charlie   91.0

# %%
# Grouping by 'Name' and calculating the total score
grouped_data = df.groupby('Name')['Score'].sum().reset_index()

print(grouped_data)
print('')
# Grouping by 'Name' and calculating the subject count
grouped_data = df.groupby('Name')['Subject'].count().reset_index()

print(grouped_data)
# Out:
#       Name  Score
# 0    Alice    177
# 1      Bob    179
# 2  Charlie    182
#
#       Name  Subject
# 0    Alice        2
# 1      Bob        2
# 2  Charlie        2
